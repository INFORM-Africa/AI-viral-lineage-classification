# %%
import pandas as pd
import os
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, f1_score
from sklearn.model_selection import ParameterGrid
from sklearn.preprocessing import LabelEncoder
import glob

# %%
def load_data(file_name, dataset):
    """
    Load the data from a Parquet file, encode the target variable, and split the data into training and validation sets.

    Parameters:
    - file_name (str): Name of the file to load (without '.parquet' extension and path).

    Returns:
    - X_train (DataFrame): Training features.
    - y_train (Series): Training labels.
    - X_val (DataFrame): Validation features.
    - y_val (Series): Validation labels.
    """
    data_path = f'../../../../data/features/{dataset}/{file_name}.parquet'
    data = pd.read_parquet(data_path)
    label_encoder = LabelEncoder()
    data["Label"] = label_encoder.fit_transform(data["Target"])

    X_train = data[data['Train'] == 0].drop(columns=["Target", "Train", "Label"])
    y_train = data[data['Train'] == 0]['Label']
    X_val = data[data['Train'] == 1].drop(columns=["Target", "Train", "Label"])
    y_val = data[data['Train'] == 1]['Label']

    return X_train, y_train, X_val, y_val

def evaluate_model(X_train, y_train, X_val, y_val, params, file_name):
    """
    Train a Random Forest model with the given parameters and evaluate it on both the training and validation sets.

    Parameters:
    - X_train (DataFrame): Training features.
    - y_train (Series): Training labels.
    - X_val (DataFrame): Validation features.
    - y_val (Series): Validation labels.
    - params (dict): Parameters for the Random Forest model.

    Returns:
    - result (dict): Dictionary containing the parameters and evaluation metrics for both training and validation sets.
    """
    print(f"Training Random Forest: {params}")
    rf = RandomForestClassifier(random_state=42, n_jobs=-1, **params)
    rf.fit(X_train, y_train)
    
    # Predictions for validation and training set
    y_pred_val = rf.predict(X_val)
    y_pred_train = rf.predict(X_train)

    # Evaluation metrics for validation set
    accuracy_val = accuracy_score(y_val, y_pred_val)
    macro_f1_val = f1_score(y_val, y_pred_val, average='macro')

    # Evaluation metrics for training set
    accuracy_train = accuracy_score(y_train, y_pred_train)
    macro_f1_train = f1_score(y_train, y_pred_train, average='macro')

    result = {
        'features': file_name,
        'max_depth': params.get('max_depth'),
        'criterion': params.get('criterion'),
        'class_weight': params.get('class_weight'),
        'accuracy_val': accuracy_val,
        'macro_f1_val': macro_f1_val,
        'accuracy_train': accuracy_train,
        'macro_f1_train': macro_f1_train
    }

    return result

def grid_search(X_train, y_train, X_val, y_val, param_grid, file_name):
    """
    Perform a grid search over the specified parameter grid for a Random Forest model and save the results.

    Parameters:
    - X_train (DataFrame): Training features.
    - y_train (Series): Training labels.
    - X_val (DataFrame): Validation features.
    - y_val (Series): Validation labels.
    - param_grid (dict): Grid of parameters to search over.
    - file_name (str): Base name for the output CSV file to store the results.
    """
    results = []

    for params in ParameterGrid(param_grid):
        result = evaluate_model(X_train, y_train, X_val, y_val, params, file_name)
        results.append(result)
        print(f"Params: {params}, Accuracy: {result['accuracy_val']}, Macro F1: {result['macro_f1_val']}")

    results_df = pd.DataFrame(results)
    return results_df

# %%
file_names = [os.path.splitext(os.path.basename(file))[0] for file in glob.glob("../../../../data/features/SARS/*.parquet")]
dataset = "SARS"

print(file_names)

file = file_names[5]

X_train, y_train, X_val, y_val = load_data(file, dataset)

param_grid = {
    'max_depth': list(range(1, 41)) + [None],
    'criterion': ['gini'],
    'class_weight': [None]
}

results_df = grid_search(X_train, y_train, X_val, y_val, param_grid, file)
# Out:
# ['Mash_distance_remove_21', '7-mer_FFP_remove', 'ACS_remove', '7-mer_remove', 'FCGR_remove_256', 'DSP_replace_real', 'RTD_7-mer_remove', 'FCGR_remove_128', '7-spaced_remove']
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 1}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 1}, Accuracy: 0.07001489678655033, Macro F1: 0.02492242420293224
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 2}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 2}, Accuracy: 0.10183017663332623, Macro F1: 0.039508143841453486
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 3}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 3}, Accuracy: 0.12226005533092148, Macro F1: 0.05036987418956427
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 4}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 4}, Accuracy: 0.15013832730368162, Macro F1: 0.06763632619281996
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 5}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 5}, Accuracy: 0.18652904873377316, Macro F1: 0.0900252012519735
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 6}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 6}, Accuracy: 0.281336454564801, Macro F1: 0.1194755570757864
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 7}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 7}, Accuracy: 0.34188125133007025, Macro F1: 0.14086022052240177
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 8}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 8}, Accuracy: 0.41700361779101935, Macro F1: 0.1889683545394168
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 9}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 9}, Accuracy: 0.45158544371142795, Macro F1: 0.22155546385123936
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 10}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 10}, Accuracy: 0.47499467971908915, Macro F1: 0.24093129574159539
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 11}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 11}, Accuracy: 0.5076612045115982, Macro F1: 0.28462072181542203
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 12}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 12}, Accuracy: 0.539795701213024, Macro F1: 0.3373622185451329
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 13}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 13}, Accuracy: 0.5719301979144499, Macro F1: 0.3778268901677158
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 14}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 14}, Accuracy: 0.598957224941477, Macro F1: 0.42675430644492673
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 15}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 15}, Accuracy: 0.6061928069802086, Macro F1: 0.4707987488426466
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 16}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 16}, Accuracy: 0.632794211534369, Macro F1: 0.517641647362198
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 17}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 17}, Accuracy: 0.6553522025962971, Macro F1: 0.5576896835312398
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 18}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 18}, Accuracy: 0.6641838689082784, Macro F1: 0.6082369532443518
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 19}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 19}, Accuracy: 0.6770589487124921, Macro F1: 0.6609049753814836
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 20}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 20}, Accuracy: 0.6882315386252394, Macro F1: 0.6828093560406554
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 21}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 21}, Accuracy: 0.6922749521174718, Macro F1: 0.720798825770607
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 22}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 22}, Accuracy: 0.6907852734624388, Macro F1: 0.7278574062114518
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 23}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 23}, Accuracy: 0.6994041285379868, Macro F1: 0.7528877735950954
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 24}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 24}, Accuracy: 0.7022770802298361, Macro F1: 0.7387507848167552
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 25}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 25}, Accuracy: 0.6996169397744201, Macro F1: 0.747521223907017
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 26}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 26}, Accuracy: 0.6992977229197702, Macro F1: 0.7593463835551938
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 27}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 27}, Accuracy: 0.7042987869759524, Macro F1: 0.7659683932789703
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 28}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 28}, Accuracy: 0.7052564375399021, Macro F1: 0.7673956557638721
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 29}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 29}, Accuracy: 0.7052564375399021, Macro F1: 0.7730528782760513
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 30}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 30}, Accuracy: 0.7066397105767185, Macro F1: 0.7669792339710995
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 31}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 31}, Accuracy: 0.7081293892317514, Macro F1: 0.7722313597954165
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 32}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 32}, Accuracy: 0.7089806341774846, Macro F1: 0.7756164379937024
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 33}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 33}, Accuracy: 0.7101510959778676, Macro F1: 0.7817600834102941
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 34}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 34}, Accuracy: 0.7120663971057671, Macro F1: 0.7879498459017853
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 35}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 35}, Accuracy: 0.7129176420515003, Macro F1: 0.789540782203688
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 36}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 36}, Accuracy: 0.7095126622685678, Macro F1: 0.7863544827876899
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 37}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 37}, Accuracy: 0.7129176420515003, Macro F1: 0.7855602869920971
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 38}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 38}, Accuracy: 0.7091934454139178, Macro F1: 0.7822606422308946
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 39}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 39}, Accuracy: 0.7111087465418174, Macro F1: 0.7861381074277077
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': 40}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': 40}, Accuracy: 0.7125984251968503, Macro F1: 0.7841185805817795
# Training Random Forest: {'class_weight': None, 'criterion': 'gini', 'max_depth': None}
# Params: {'class_weight': None, 'criterion': 'gini', 'max_depth': None}, Accuracy: 0.7125984251968503, Macro F1: 0.7806375508023379

# %%
import pandas as pd
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(results_df['max_depth'], results_df['accuracy_train'], label='Training Accuracy', marker='o')
plt.plot(results_df['max_depth'], results_df['accuracy_val'], label='Validation Accuracy', marker='o')

plt.title('Training vs Validation Accuracy with Increasing max_depth')
plt.xlabel('Max Depth')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
